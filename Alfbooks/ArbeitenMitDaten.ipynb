# %% [markdown]
# # Datenabholen Daten auslesen
# * User abzapfen (eingeben)
# * Textdokumente / Dateien auslesen
# * API Calls
# * Datenbanken abfragen
# * Webseiten parsen --- Crawler--- Daten Spider (Botnetze)
# * ...

# %% [markdown]
# ## Eingabe von Usercommands

# %%
my_input = input()

# %%
print(my_input, type(my_input))
# Out:
# 123 <class 'str'>

# %%
# Fehlerhandling in Python
try:
    my_input = input("pls. enda a numba:")
    my_number = int(my_input)
    print("input:", my_input, " - as number:", my_number)
except ValueError as value_error:
    print("pls. enter a valid integer number: " + str(value_error))
except Exception as general_error:
    print("sth. went wrong: " + str(general_error))
# Out:
# sth. went wrong: invalid literal for int() with base 10: 'asdas'

# %%
my_input = input("pls. enda a numba:")
my_number = int(my_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-cdbc72a11002> in <module>
#       1 my_input = input("pls. enda a numba:")
# ----> 2 my_number = int(my_input)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ## auslesen aus Dateien

# %%
my_filename = "datendatei.txt"
my_file = open(my_filename, "r")
my_file_str = open(my_filename, "r").read()

# %%
my_file
# Out:
# <_io.TextIOWrapper name='datendatei.txt' mode='r' encoding='cp1252'>

# %%
# print(my_file_str) # is not textIOWrapper anymore

# %%
# help(my_file)

# %%
my_str_file = my_file.read()

# %%
type(my_str_file)
# Out:
# str

# %%
my_file_list = my_str_file.split()

# %%
len(set(my_file_list))
# Out:
# 21

# %%
try:
    my_err_file = open("beispieldaten.txt", encoding="banana")
except FileNotFoundError as ferr:
    print("give me a different name of your file: " + str(ferr))
except ValueError as mode_err:
    print("hey dude you selected a unknown mode: " + str(mode_err))
except Exception as general_err:
    print("sth. went wrong:" + str(general_err))
# Out:
# sth. went wrong:unknown encoding: banana

# %%
        # Hochschule
    # Hoch            # Schule
## Ho ## ch       ## Schu ## le


######### spalte 1 ## spalte 2 ## Spalte 3
# Zeile 1    ele11    ele12       ele13
# Zeile 2    ele21    ele22       ele23
# Zeile 3    ele31    ele32       ele33

# matrix[3][2] ==> ele32

# if matrix[*][*] == True 
# for: for:

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
 df = pd.DataFrame({'age':    [ 3,  29],
                    'height': [94, 170],
                    'weight': [31, 115]})

# %%
df
# Out:
#    age  height  weight
# 0    3      94      31
# 1   29     170     115

# %%
# help(pd.DataFrame)

# %%
my_open_data = open("Download.csv").read()

# %%
list_opd = my_open_data.split()
list_opd[0]
# Out:
# 'dateRep,day,month,year,cases,deaths,countriesAndTerritories,geoId,countryterritoryCode,popData2019,continentExp,Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'

# %%
# herkömmliche Methode des Daten Dateien auslesen ist bullshit

# %%
txt_dataframe_data = pd.read_fwf("datendatei.txt", names=["spaltenname"])

# %%
variable_temp = txt_dataframe_data.dtypes

# %%
variable_temp
# Out:
# spaltenname    int64
# dtype: object

# %%
my_file_data = pd.read_csv("Download.csv")

# %%
my_file_data.keys()
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
my_file_data.iloc[42]
# Out:
# dateRep                                                        02/11/2020
# day                                                                     2
# month                                                                  11
# year                                                                 2020
# cases                                                                 132
# deaths                                                                  5
# countriesAndTerritories                                       Afghanistan
# geoId                                                                  AF
# countryterritoryCode                                                  AFG
# popData2019                                                    38041757.0
# continentExp                                                         Asia
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000       3.766913
# Name: 42, dtype: object

# %%
my_file_data.dtypes
# Out:
# dateRep                                                        object
# day                                                             int64
# month                                                           int64
# year                                                            int64
# cases                                                           int64
# deaths                                                          int64
# countriesAndTerritories                                        object
# geoId                                                          object
# countryterritoryCode                                           object
# popData2019                                                   float64
# continentExp                                                   object
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000    float64
# dtype: object

# %%
# countriesAndTerritories
# countryterritoryCode

# %%
my_file_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
my_file_data.tail()
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 61895  25/03/2020   25      3  2020      0       0                Zimbabwe
# 61896  24/03/2020   24      3  2020      0       1                Zimbabwe
# 61897  23/03/2020   23      3  2020      0       0                Zimbabwe
# 61898  22/03/2020   22      3  2020      1       0                Zimbabwe
# 61899  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 61895    ZW                  ZWE   14645473.0       Africa
# 61896    ZW                  ZWE   14645473.0       Africa
# 61897    ZW                  ZWE   14645473.0       Africa
# 61898    ZW                  ZWE   14645473.0       Africa
# 61899    ZW                  ZWE   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 61895                                                NaN
# ...

# %%
# which countries
countries_in_dataset = set(my_file_data["countriesAndTerritories"])
len(countries_in_dataset)
# Out:
# 214

# %%
my_file_data.Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 # specific column name it is not possible to use dot operator
my_file_data.countriesAndTerritories # here its working
# Out:
#   File "<ipython-input-111-1fac39e66254>", line 1
#     my_file_data.Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
#                                                           ^
# SyntaxError: invalid decimal literal

# %%
if "Deutschland" in countries_in_dataset:
    print("Deutschland")
elif "Germany" in countries_in_dataset:
    print("Germany")
else:
    print("not in list")
# Out:
# Germany

# %%
germany_df = my_file_data[my_file_data["countriesAndTerritories"] == "Germany"]

# %%
germany_df = germany_df.reset_index()

# %%
del germany_df["index"]

# %%
germany_df["cases"].plot()
# Out:
# <AxesSubplot:>

# %%
# if no plot use matplot config for notebooks

# %%
# %matplotlib inline

# %%
germany_df
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0    14/12/2020   14     12  2020  16362     188                 Germany
# 1    13/12/2020   13     12  2020  20200     321                 Germany
# 2    12/12/2020   12     12  2020  28438     496                 Germany
# 3    11/12/2020   11     12  2020  29875     598                 Germany
# 4    10/12/2020   10     12  2020  23679     440                 Germany
# ..          ...  ...    ...   ...    ...     ...                     ...
# 345  04/01/2020    4      1  2020      0       0                 Germany
# 346  03/01/2020    3      1  2020      0       0                 Germany
# 347  02/01/2020    2      1  2020      0       0                 Germany
# 348  01/01/2020    1      1  2020      0       0                 Germany
# 349  31/12/2019   31     12  2019      0       0                 Germany
#
#     geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
germany_df["death divide cases"] = germany_df["deaths"] / germany_df["cases"]

# %%
germany_df
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0    14/12/2020   14     12  2020  16362     188                 Germany
# 1    13/12/2020   13     12  2020  20200     321                 Germany
# 2    12/12/2020   12     12  2020  28438     496                 Germany
# 3    11/12/2020   11     12  2020  29875     598                 Germany
# 4    10/12/2020   10     12  2020  23679     440                 Germany
# ..          ...  ...    ...   ...    ...     ...                     ...
# 345  04/01/2020    4      1  2020      0       0                 Germany
# 346  03/01/2020    3      1  2020      0       0                 Germany
# 347  02/01/2020    2      1  2020      0       0                 Germany
# 348  01/01/2020    1      1  2020      0       0                 Germany
# 349  31/12/2019   31     12  2019      0       0                 Germany
#
#     geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
germany_df["death divide cases"].plot()
# Out:
# <AxesSubplot:>

# %%
germany_df = germany_df[::-1]

# %%
germany_df = germany_df.reset_index()
del germany_df["index"]

# %%
germany_df
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0    31/12/2019   31     12  2019      0       0                 Germany
# 1    01/01/2020    1      1  2020      0       0                 Germany
# 2    02/01/2020    2      1  2020      0       0                 Germany
# 3    03/01/2020    3      1  2020      0       0                 Germany
# 4    04/01/2020    4      1  2020      0       0                 Germany
# ..          ...  ...    ...   ...    ...     ...                     ...
# 345  10/12/2020   10     12  2020  23679     440                 Germany
# 346  11/12/2020   11     12  2020  29875     598                 Germany
# 347  12/12/2020   12     12  2020  28438     496                 Germany
# 348  13/12/2020   13     12  2020  20200     321                 Germany
# 349  14/12/2020   14     12  2020  16362     188                 Germany
#
#     geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
germany_df.plot(x="dateRep", y="death divide cases")
# Out:
# <AxesSubplot:xlabel='dateRep'>
